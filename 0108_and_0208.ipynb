# %% [markdown]
# **File Handling**
# - Get the package name to read each file.
# - How to read the text file
# - In order to read any file, we need 3 points.
# - 1: where is the file located: directory or folder name.
#
#   'C:\Users\Srinivas Rao\Downloads\TXT files'
# - 2: what is the file name
#
#   'mbox-short'
# - 3: what is the extension of the file.
#
#   '.txt'
#
# => location\filename.typeoffile

# %%
path_0 = 'C:\Users\Srinivas Rao\Downloads\TXT files\naresh_it_data_files\mbox-short.txt'
path_1 = 'C:\Users\Srinivas Rao\Downloads\TXT files\naresh_it_data_files\winequality_red.csv'
path_2 = 'C:\Users\Srinivas Rao\Downloads\TXT files\naresh_it_data_files\Visadataset.csv'
path_3 = 'C:\Users\Srinivas Rao\Downloads\TXT files\naresh_it_data_files\Salary_Data.csv'
path_4 = 'C:\Users\Srinivas Rao\Downloads\TXT files\naresh_it_data_files\NAMES.csv'
path_5 = 'C:\Users\Srinivas Rao\Downloads\TXT files\naresh_it_data_files\metamorphosis clean.txt'
path_6 = 'C:\Users\Srinivas Rao\Downloads\TXT files\naresh_it_data_files\IMDB Dataset_sample.xlsx'
path_7 = 'C:\Users\Srinivas Rao\Downloads\TXT files\naresh_it_data_files\california_housing.csv'
path_8 = 'C:\Users\Srinivas Rao\Downloads\TXT files\naresh_it_data_files\bank.csv'
path_9 = 'C:\Users\Srinivas Rao\Downloads\TXT files\naresh_it_data_files\android-games.csv'

# %%
- This is call a Unicode error
- Uni means one
- Unicode means 
- We can avoid unicode error by providing **r** at the begining of the line

# %%
'C:\\Users\\Srinivas Rao\\Downloads\\TXT files\\naresh_it_data_files\\mbox-short.txt'

# %%
r'C:\Users\Srinivas Rao\Downloads\TXT files\naresh_it_data_files\mbox-short.txt'

# %%
# Folder name
# Different user having different directory
# Observe root folder or root directory

# %% [markdown]
# ### Read the File

# %%
path=r'C:\Users\Srinivas Rao\Downloads\TXT files\naresh_it_data_files\mbox-short.txt'
open(path)

# %%
# 'r' open for reading (default)
# 'w' open for writing, truncating the file first
      we load the data which has already have information
      that information will erase, that is called as "Truncating"
# 'x' create a new file and open it for writing
      Imagine that there is no empty file in your local
      It will create the file and write the information
# 'a' open for writing, appending to the end of the file if it exists
      Already information is there, we want to add some data.
# 'b' binary mode
      binary is a data type: b:'abc'
# 't' text mode (default)
# '+' open a disk file for updating (reading and writing)

# %%
import os
os.getcwd()

# %%
path='mbox-short.txt'
file = open(path)
# data=file.read()
# print(data.count('\n'))
line=[]
line_idx=[]
count = 0;
rl=file.readlines()
for ln in range(len(rl)):
    count=count+1
    line_idx.append(len(rl[ln]))
    line.append(count)
print(len(line))
print('\n\n')
print(line_idx[0])
print(line_idx[1])
print(line_idx[2])

print(line_idx[0+1])
print(line_idx[1+1])
print(line_idx[2+1])

print(line_idx[0+2])
print(line_idx[1+2])
print(line_idx[2+2])

print(line_idx)
# Out:
# 1910
#
#
#
# 57
# 50
# 55
# 50
# 55
# 60
# 55
# 60
# 34
# ...

# %%
path='mbox-short.txt'
file = open(path)

line=[]
line_idx=[]
count=0
rl=file.readlines()
for ln in range(len(rl)):
    count=count+1
    line_idx.append(len(rl[ln]))     # Adding length of each line into list
    line.append(count)               # Adding line numbers into list
print('\nTotal Lines:',count)        # Total No. of the lines
# # Trials
# print(line)                       # 'mbox-short.txt' file lines
# print('\n\n')
# print(len(line))                  # Total line numbers
# print('\n\n')
# print(line_idx)                   # Length of the each line.

# Testing
# for i in range(4):
#     print(rl[i],'\r')            # Test printing
    
print('\nLine - No', '   Max Length\n=========    ==========') 
for ln in range(len(line)):
    print(f'  {ln+1}      \t{line_idx[ln]}')
# Out:
# Total Lines: 1910
#
# Line - No    Max Length
# =========    ==========
#   1      	57
#   2      	50
#   3      	55
#   4      	60
#   5      	34
#   6      	23
#   7      	38
#   8      	48
#   9      	34
#   10      	79
#   11      	61
#   12      	32
#   13      	78
#   14      	54
#   15      	28
#   16      	56
#   17      	57
#   18      	39
#   19      	66
#   20      	18
#   21      	32
#   22      	56
#   23      	73
#   24      	48
#   25      	47
#   26      	82
#   27      	54
#   28      	77
#   29      	63
#   30      	84
#   31      	70
#   32      	34
#   33      	80
#   34      	68
#   35      	37
#   36      	108
#   37      	35
#   38      	33
#   39      	124
#   40      	57
#   41      	55
#   42      	40
#   43      	25
#   44      	44
#   45      	27
#   46      	28
#   47      	1
#   48      	68
#   49      	1
#   50      	35
#   51      	51
#   52      	20
#   53      	1
#   54      	10
#   55      	115
#   56      	108
#   57      	5
#   58      	109
# ...

# %%
path='mbox-short.txt'
file = open(path)
# # data=file.read()
# # print(data.count('\n'))

line=[]
line_idx=[]
new_ln_idx=[]
a, b, c, count = 0, 0, 0, 0
a_idx, b_idx, c_idx = 0, 0, 0

rl=file.readlines()
for ln in range(len(rl)):
    count=count+1
    line_idx.append(len(rl[ln]))
    line.append(count)
# # print(len(line))
# # print('\n\n')
# # print(line_idx)
if len(line) % 3 !=0:                # To skip IndexError:list index out of range
    reminder=len(line) % 3
    line_ln=len(line)-reminder-1
else:
    line_ln=len(line)
    
for lie in range(line_ln):
    for i in range(0,3):
        # print(line[lie]+i, ' ', line_idx[line[lie]+i])
        if i==0:
            a=line_idx[line[lie]+i]
            a_idx=line[lie]+i
            print(line[lie]+i, ' ', line_idx[line[lie]+i])
        elif i==1:
            b=line_idx[line[lie]+i]
            b_idx=line[lie]+i
            print(line[lie]+i, ' ', line_idx[line[lie]+i])
        else:
            c=line_idx[line[lie]+i]
            c_idx=line[lie]+i
            print(line[lie]+i, ' ', line_idx[line[lie]+i])

        if a==b==c:
            new_ln_idx.append(a_idx)
            print('=================',a_idx,'=================')
    a,b,c=0,0,0
    print('\n')
    count=count+1
# # print(count)
print(len(new_ln_idx))
# Out:
# 1   50
# 2   55
# 3   60
#
#
# 2   55
# 3   60
# 4   34
#
#
# 3   60
# 4   34
# 5   23
#
#
# 4   34
# 5   23
# 6   38
#
#
# 5   23
# 6   38
# 7   48
#
#
# 6   38
# 7   48
# 8   34
#
#
# 7   48
# 8   34
# 9   79
#
#
# 8   34
# 9   79
# 10   61
#
#
# 9   79
# 10   61
# 11   32
#
#
# 10   61
# 11   32
# 12   78
#
#
# 11   32
# 12   78
# 13   54
#
#
# 12   78
# 13   54
# 14   28
#
#
# 13   54
# 14   28
# 15   56
#
#
# 14   28
# 15   56
# 16   57
#
#
# 15   56
# 16   57
# 17   39
#
#
# 16   57
# 17   39
# 18   66
#
#
# 17   39
# 18   66
# 19   18
#
#
# 18   66
# 19   18
# 20   32
#
#
# 19   18
# 20   32
# 21   56
#
#
# 20   32
# 21   56
# 22   73
#
#
# 21   56
# 22   73
# 23   48
#
#
# 22   73
# 23   48
# 24   47
#
#
# 23   48
# 24   47
# 25   82
#
#
# 24   47
# 25   82
# 26   54
#
#
# 25   82
# 26   54
# 27   77
#
#
# 26   54
# 27   77
# 28   63
#
#
# 27   77
# 28   63
# 29   84
#
#
# 28   63
# 29   84
# 30   70
#
#
# 29   84
# 30   70
# 31   34
#
#
# 30   70
# 31   34
# 32   80
#
#
# ...

# %%
# 1910
remainder = 1910 % 3
print(remainder) # Output: 5
