# %%
# Q5) wap ask the user iterate using a string
# string='welcome'
# print the postive index of w is 0
#       the positive index of e is 1
#       the positive index of l is 1
str='welcome'
ln = len(str)
for i in (0,ln):
    print(i)

# %%
# Q14) string1='ola ola ola'
# Number of ola  = 3
string1='ola ola ola '
count=0
ln_str=0
for i in range(len(string1)):
    if ord(string1[i]) == 32:
        count=count+1
        print(i)
print('Total', count)

# %%
string1='o1a o2a o3a'
max=0
min=0
tmp=len(string1)
step = 0
sub_str=0
for i in range(min, tmp):
    if ord(string1[i]) == 32:
        for j in(step, min):
            print('step', step)
            print('min',min)
            # print('i',i)
            step=step+min+1
        # print('tmp',tmp)
    min=i

# %%
# good
string1='o1a o2a o3a'
min=0
tmp=len(string1)
f4m = 0
count1 = 0
step_str=''
for i in range(min, tmp):
    if ord(string1[i]) == 32:
        for j in range(f4m, i):
            # print(string1[j])
            step_str=step_str+string1[j]
            j=f4m+1
        f4m=j+i
        print(step_str)
        step_str=''

# %%
string1='o1a o2a o3a '
min=0
max=len(string1)
sub_max=0
f4m = 0
count1 = 0
step_str=''
for i in range(min, max):
    if ord(string1[i]) == 32:
        for j in range(f4m, i):
            # print(string1[j])
            step_str=step_str+string1[j]
            j=f4m+1
        f4m=j+i
        print(step_str)
        step_str=''

# %%
string1='o1a o1a o1a '
min=0
max=len(string1)
sub_max=0
f4m = 0
counter = 0
step_str=''
for i in range(min, max):
    if ord(string1[i]) == 32:
        for j in range(f4m, i):
            # print(string1[j])
            step_str=step_str+string1[j]
        # print(f4m)
        # print(i)
        if step_str == 'o1a':
            counter=counter+1
        print(step_str)
        step_str=''
        f4m=i+1
print(counter)

# %%
text=input('Enter text to search repeated word: ') +' '
search_txt = input('Enter search text: ')
min=0
max=len(text)
# sub_max=0
f4m = 0
counter = 0
buffer=''
for i in range(min, max):
    if ord(text[i]) == 32:
        for j in range(f4m, i):
            buffer=buffer+text[j]
        if buffer == search_txt:
            counter=counter+1
        buffer=''
        f4m=i+1
print(f'Your search word: {search_txt} having {counter} time(s)')

# %%
# Final
text=input('Enter text to search repeated word: ') +' '
search_txt = input('Enter search text: ')
min=0
max=len(text)
# sub_max=0
f4m = 0
counter = 0
buffer=''
if ord(search_txt[0]) != 32:
    for i in range(min, max):
        if ord(text[i]) == 32:
            for j in range(f4m, i):
                buffer=buffer+text[j]
            if buffer == search_txt:
                counter=counter+1
            buffer=''
            f4m=i+1
    print(f'Your search word: {search_txt} having {counter} time(s)')
else:
    print('***** Your search text should not be space ******')

# %%
text=input('Enter text to search repeated word: ') +' '
search_txt = input('Enter search text: ')
min=0
max=len(text)
s_len=len(search_txt)
f4m = 0
counter = 0
buffer=''
status = search_txt in text
for i in range(min, max):
    if ord(text[i]) == 32:
        if s_len == i:
            for j in range(f4m, i):
                buffer=buffer+text[j]
            if len(buffer) == s_len and buffer == search_txt:
                counter=counter+1
            elif    
                print('No')
# print(f'Your search word: {search_txt} having {counter} time(s)')

# %%
text=input('Enter text to search repeated word: ') +' '
search_txt = input('Enter search text: ') + ' '
min=0
max=len(text)
s_len=len(search_txt)
f4m = 0
counter = 0
buffer=''
bufferx=''
status = search_txt in text
for i in range(min, max):
    if ord(text[i]) == 32:
        for j in range(f4m, s_len):
            buffer=buffer+text[j]
        if len(buffer) == s_len and buffer == search_txt:
            counter=counter+1
            buffer=''
            f4m=f4m+i+1
            print(f4m, i)
            
print(counter)

# %%
hi = 'hello world Iam'
buf_len=4+1
hi2=hi[:buf_len]
hi3 = hi[buf_len:len(hi)]
print(hi3)

# %%
text='hello hi how are you dear are you'+' '
search_txt = 'are you'
min=0
max=len(text)
s_len=len(search_txt)
sp_count=0
wd_counter=1
f4m=0
to2=0
buffer=''
print('Finding each word array locations in a string\n=================================================')
for i in range(min, max):
    if ord(text[i]) == 32:
        sp_count=sp_count+1
        to2=i-1
        print(f'Word: {wd_counter} is from {f4m} to {to2} and + space at {i}th location') # f4m,to2, i)
        f4m=i+1
        wd_counter=wd_counter+1
print(f'\nTotal spaces: ',sp_count)

# %%
text='hello hi how are you dear are you'+' '
search_txt = 'are you'+' '
min=0
min2=0
max=len(text)
s_len=len(search_txt)
sp_count=0
sp_count2=0
wd_counter=1 
wd_counter2=1
f4m=0
f4m2=0
to2=0
to22=0
buffer=''
buffer2=''
print('Finding each word array locations in a string\n=================================================')
for k in range(min2, s_len):
    if ord(search_txt[k]) == 32:
        sp_count2=sp_count2+1
        to22=k
        for l in range(f4m2, to22):
            buffer2=buffer2+search_txt[l]
        f4m2=k+1
        wd_counter2=wd_counter2+1
    print(buffer2)
    buffer2=''
print(f'\nTotal spaces: ',sp_count2)

# %%
text='bappi chinnu bappi bappi bittu chinnu bittu bittu chinnu bittu'+' '
search_txt = 'bittu'+' '
min=0
min2=0
max=len(text)
s_len=len(search_txt)
sp_count=0
sp_count2=0
wd_counter=1 
wd_counter2=1
f4m=0
f4m2=0
to2=0
to22=0
buffer=''
buffer2=''
xbuffer=''
ybuffer=''
gsp_count=1
count=0
print('Finding each word array locations in a string\n=================================================')
for k in range(min2, s_len):
    if ord(search_txt[k]) == 32:
        sp_count2=sp_count2+1
        gsp_count=gsp_count+sp_count2
        to22=k
        for l in range(f4m2, to22):
            buffer2=buffer2+search_txt[l]
        f4m2=k+1
        wd_counter2=wd_counter2+1
    # print(buffer2)
    # buffer2=''
if gsp_count < 3:
    for i in range(min, max):
        if ord(text[i]) == 32:
            sp_count=sp_count+1
            to2=i
            for j in range(f4m, to2):
                buffer=buffer+text[j]
            f4m=i+1
            wd_counter=wd_counter+1
            # print(buffer, sp_count, xbuffer+buffer)
            if gsp_count==1:
                if buffer == search_txt:
                    count=count+1
            if gsp_count==2:
                if xbuffer+buffer == search_txt:
                    count=count+1
                xbuffer = buffer+ ' '
        buffer=''
        ybuffer=''
    print(f'\nTotal words count in a string: ', count) 
else:
    print('Search words should not be morethan 2')
# Out:
# Finding each word array locations in a string
# ...
#
# Total words count in a string:  0
